# %% [markdown]
# # 保存并加载模型

# %%
import tensorflow as tf
import numpy as np

def train_model():

    # prepare the data
    x_data = np.random.rand(100).astype(np.float32)
    print (x_data)
    y_data = x_data * 0.1 + 0.2
    print (y_data)

    # define the weights
    W = tf.Variable(tf.random_uniform([1], -20.0, 20.0), dtype=tf.float32, name='w')
    b = tf.Variable(tf.random_uniform([1], -10.0, 10.0), dtype=tf.float32, name='b')
    y = W * x_data + b

    # define the loss
    loss = tf.reduce_mean(tf.square(y - y_data))
    train_step = tf.train.GradientDescentOptimizer(0.5).minimize(loss)

    # save model
    saver = tf.train.Saver(max_to_keep=4)

    with tf.Session() as sess:

        sess.run(tf.global_variables_initializer())
        print ("------------------------------------------------------")
        print ("before the train, the W is %6f, the b is %6f" % (sess.run(W), sess.run(b)))

        for epoch in range(300):
            if epoch % 10 == 0:
                print ("------------------------------------------------------")
                print ("after epoch %d, the loss is %6f" % (epoch, sess.run(loss)))
                print ("the W is %f, the b is %f" % (sess.run(W), sess.run(b)))
                saver.save(sess, "model/my-model", global_step=epoch)
                print ("save the model")
            sess.run(train_step)
        print ("------------------------------------------------------")

def load_model():
    with tf.Session() as sess:
        saver = tf.train.import_meta_graph('model/my-model-290.meta')
        saver.restore(sess, tf.train.latest_checkpoint("model/"))
        print (sess.run('w:0')
        print (sess.run('b:0'))

train_model()
load_model()
# Out:
# [0.02957517 0.09395359 0.31066823 0.9452681  0.4562804  0.5608454
#  0.86014396 0.02748431 0.9473182  0.24527614 0.631445   0.5984606
#  0.5396418  0.6575359  0.3028885  0.54458356 0.2677046  0.04587485
#  0.55890715 0.89851665 0.11578908 0.31376815 0.47741616 0.8750368
#  0.38713303 0.9341808  0.78160775 0.55967    0.6271788  0.9777753
#  0.16451517 0.65145576 0.34552932 0.8100401  0.22550371 0.34260222
#  0.25637212 0.57243687 0.13380228 0.69484544 0.4202368  0.71863633
#  0.23245984 0.5939264  0.2751467  0.20716822 0.06980288 0.88099575
#  0.91251975 0.80839944 0.2101358  0.34787688 0.22290926 0.8297967
#  0.6079359  0.62811893 0.7280855  0.12633222 0.8977422  0.8639572
#  0.3164567  0.7449367  0.06883019 0.9134769  0.67452776 0.9294895
#  0.99163514 0.4974357  0.507604   0.32554352 0.51754624 0.8435545
#  0.11459221 0.3325354  0.02187996 0.713525   0.0036157  0.3621272
#  0.8872655  0.39172155 0.5724974  0.19397004 0.9981355  0.7490453
#  0.18285236 0.37200204 0.41539282 0.33054045 0.40494415 0.17198241
#  0.7052585  0.47544935 0.16807972 0.12508427 0.5697735  0.9984302
#  0.47532097 0.9690467  0.7268261  0.39947745]
# [0.20295753 0.20939536 0.23106682 0.29452682 0.24562804 0.25608453
#  0.2860144  0.20274843 0.29473183 0.22452761 0.2631445  0.25984606
#  0.2539642  0.2657536  0.23028885 0.25445837 0.22677046 0.20458749
#  0.25589073 0.28985167 0.2115789  0.23137683 0.24774162 0.2875037
#  0.23871331 0.29341808 0.27816078 0.255967   0.26271787 0.29777753
#  0.21645153 0.26514557 0.23455293 0.281004   0.22255038 0.23426023
#  0.22563721 0.2572437  0.21338023 0.26948455 0.24202368 0.27186364
#  0.223246   0.25939265 0.22751467 0.22071682 0.20698029 0.2880996
#  0.291252   0.28083995 0.22101358 0.23478769 0.22229093 0.28297967
#  0.2607936  0.2628119  0.27280855 0.21263322 0.28977424 0.28639573
#  0.23164567 0.27449366 0.20688303 0.29134768 0.26745278 0.29294896
#  0.29916352 0.24974358 0.2507604  0.23255436 0.25175464 0.28435546
#  0.21145922 0.23325354 0.202188   0.2713525  0.20036158 0.23621273
#  0.28872657 0.23917216 0.25724974 0.21939701 0.29981357 0.27490455
#  0.21828523 0.2372002  0.24153928 0.23305404 0.24049442 0.21719824
#  0.27052584 0.24754494 0.21680798 0.21250843 0.25697735 0.299843
#  0.2475321  0.29690468 0.2726826  0.23994775]
# ------------------------------------------------------
# before the train, the W is 10.728369, the b is 8.377220
# ------------------------------------------------------
# after epoch 0, the loss is 192.884537
# the W is 10.728369, the b is 8.377220
# save the model
# ------------------------------------------------------
# after epoch 10, the loss is 0.504816
# the W is 2.546021, the b is -1.121866
# save the model
# ------------------------------------------------------
# after epoch 20, the loss is 0.130782
# the W is 1.344990, the b is -0.472827
# save the model
# ------------------------------------------------------
# after epoch 30, the loss is 0.033882
# the W is 0.733685, the b is -0.142461
# save the model
# ------------------------------------------------------
# after epoch 40, the loss is 0.008778
# the W is 0.422538, the b is 0.025691
# save the model
# ------------------------------------------------------
# after epoch 50, the loss is 0.002274
# the W is 0.264168, the b is 0.111279
# save the model
# ------------------------------------------------------
# after epoch 60, the loss is 0.000589
# the W is 0.183560, the b is 0.154842
# save the model
# ------------------------------------------------------
# after epoch 70, the loss is 0.000153
# the W is 0.142531, the b is 0.177015
# save the model
# ------------------------------------------------------
# after epoch 80, the loss is 0.000040
# the W is 0.121648, the b is 0.188301
# save the model
# ------------------------------------------------------
# after epoch 90, the loss is 0.000010
# the W is 0.111018, the b is 0.194045
# save the model
# ------------------------------------------------------
# after epoch 100, the loss is 0.000003
# the W is 0.105608, the b is 0.196969
# save the model
# ------------------------------------------------------
# after epoch 110, the loss is 0.000001
# the W is 0.102855, the b is 0.198457
# save the model
# ------------------------------------------------------
# after epoch 120, the loss is 0.000000
# the W is 0.101453, the b is 0.199215
# save the model
# ------------------------------------------------------
# after epoch 130, the loss is 0.000000
# the W is 0.100740, the b is 0.199600
# save the model
# ------------------------------------------------------
# after epoch 140, the loss is 0.000000
# the W is 0.100376, the b is 0.199797
# save the model
# ------------------------------------------------------
# after epoch 150, the loss is 0.000000
# the W is 0.100192, the b is 0.199896
# save the model
# ------------------------------------------------------
# after epoch 160, the loss is 0.000000
# the W is 0.100098, the b is 0.199947
# save the model
# ------------------------------------------------------
# after epoch 170, the loss is 0.000000
# the W is 0.100050, the b is 0.199973
# save the model
# ------------------------------------------------------
# after epoch 180, the loss is 0.000000
# the W is 0.100025, the b is 0.199986
# save the model
# ------------------------------------------------------
# after epoch 190, the loss is 0.000000
# the W is 0.100013, the b is 0.199993
# save the model
# ------------------------------------------------------
# after epoch 200, the loss is 0.000000
# the W is 0.100007, the b is 0.199996
# save the model
# ------------------------------------------------------
# after epoch 210, the loss is 0.000000
# the W is 0.100003, the b is 0.199998
# save the model
# ------------------------------------------------------
# after epoch 220, the loss is 0.000000
# the W is 0.100002, the b is 0.199999
# save the model
# ------------------------------------------------------
# after epoch 230, the loss is 0.000000
# the W is 0.100001, the b is 0.200000
# save the model
# ------------------------------------------------------
# after epoch 240, the loss is 0.000000
# the W is 0.100000, the b is 0.200000
# save the model
# ------------------------------------------------------
# after epoch 250, the loss is 0.000000
# the W is 0.100000, the b is 0.200000
# save the model
# ------------------------------------------------------
# after epoch 260, the loss is 0.000000
# the W is 0.100000, the b is 0.200000
# save the model
# ------------------------------------------------------
# after epoch 270, the loss is 0.000000
# the W is 0.100000, the b is 0.200000
# save the model
# ------------------------------------------------------
# after epoch 280, the loss is 0.000000
# the W is 0.100000, the b is 0.200000
# save the model
# ------------------------------------------------------
# after epoch 290, the loss is 0.000000
# the W is 0.100000, the b is 0.200000
# save the model
# ------------------------------------------------------
# INFO:tensorflow:Restoring parameters from model/my-model-290
# [0.10000008]
# [0.19999996]
